# %%
import pandas as pd

# %%
import numpy as np

# %%
from numpy import int64

# %%
from matplotlib import pyplot as plt

# %%
import plotly.express as px

# %%
pd.set_option('display.float_format', lambda x: '%.f' % x)

# %%
data = pd.read_excel('/content/DadosBO2020.xls')

# %%
data.columns
# Out:
# Index(['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'DATAOCORRENCIA',
#        'HORAOCORRENCIA', 'PERIDOOCORRENCIA', 'FLAGRANTE', 'LOGRADOURO',
#        'NUMERO', 'BAIRRO', 'CIDADE', 'UF', 'LATITUDE', 'LONGITUDE',
#        'DESCRICAOLOCAL', 'SOLUCAO', 'DELEGACIA_NOME',
#        'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA', 'PLACA_VEICULO',
#        'UF_VEICULO', 'CIDADE_VEICULO', 'DESCR_COR_VEICULO', 'MARCA_VEICULO',
#        'MODELO_VEICULO', 'ANO_FABRICACAO', 'ANO_MODELO', 'DESCR_TIPO_VEICULO'],
#       dtype='object')

# %%
  0   id              21613 non-null  int64         
 1   date            21613 non-null  datetime64[ns]
 2   price           21613 non-null  float64  # Size, Color     
 3   bedrooms        21613 non-null  int64         
 4   bathrooms       21613 non-null  float64       
 5   sqft_living     21613 non-null  int64         
 6   sqft_lot        21613 non-null  int64         
 7   floors          21613 non-null  float64       
 8   waterfront      21613 non-null  int64         
 9   view            21613 non-null  int64         
 10  condition       21613 non-null  int64         
 11  grade           21613 non-null  int64         
 12  sqft_above      21613 non-null  int64         
 13  sqft_basement   21613 non-null  int64         
 14  yr_built        21613 non-null  int64         
 15  yr_renovated    21613 non-null  int64         
 16  zipcode         21613 non-null  int64         
 17  lat             21613 non-null  float64       
 18  long            21613 non-null  float64       
 19  sqft_living15   21613 non-null  int64         
 20  sqft_lot15      21613 non-null  int64         
 21  house_level     21613 non-null  object        
 22  dormitory_type  21613 non-null  object        
 23  condition_type  21613 non-null  object
# Out:
#   File "<ipython-input-119-02a0f629a571>", line 1
#     0   id              21613 non-null  int64
#          ^
# SyntaxError: invalid syntax

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ANO_BO                   2899 non-null   int64
#  1   NUM_BO                   2899 non-null   int64
#  2   NUMERO_BOLETIM           2899 non-null   object
#  3   DATAOCORRENCIA           2899 non-null   datetime64[ns]
#  4   HORAOCORRENCIA           2557 non-null   float64
#  5   PERIDOOCORRENCIA         2899 non-null   object
#  6   FLAGRANTE                2899 non-null   object
#  7   LOGRADOURO               2680 non-null   object
#  8   NUMERO                   2899 non-null   int64
#  9   BAIRRO                   2893 non-null   object
#  10  CIDADE                   2899 non-null   object
#  11  UF                       2899 non-null   object
#  12  LATITUDE                 2417 non-null   float64
#  13  LONGITUDE                2417 non-null   float64
# ...

# %%
data_mapa = data[['NUMERO_BOLETIM', 'LATITUDE', 'LONGITUDE', 'NUM_BO','BAIRRO','MODELO_VEICULO','LOGRADOURO','HORAOCORRENCIA','PERIDOOCORRENCIA']]

# %%
data['HORAOCORRENCIA'] = data['HORAOCORRENCIA'].astype(str)

# %%
mapa = px.scatter_mapbox(data_mapa,
                         lat='LATITUDE',
                         lon='LONGITUDE',
                         hover_name='NUMERO_BOLETIM',
                         hover_data=["BAIRRO", "LOGRADOURO"],
                           
                         color_continuous_scale=px.colors.cyclical.IceFire,
                         zoom=11,
                         height=300)
mapa.update_layout(mapbox_style='open-street-map')
mapa.update_layout( height=1000, margin={'r':0, 't':0, 'l':0 ,'b':0})
mapa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1ba602c-bc36-42c8-9058-90bfb3a9c69f" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1ba602c-bc36-42c8-9058-90bfb3a9c69f")) {
#                     Plotly.newPlot(
#                         'a1ba602c-bc36-42c8-9058-90bfb3a9c69f',
# ...
